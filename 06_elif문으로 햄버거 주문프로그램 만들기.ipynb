# %%
store_message = """
bbbbbb       u        u
b    b       u        u
b     b      u        u
bbbbbbb      u        u
b    b       u        u
b     b      u        u 
bbbbbbb      uuuuuuuuuu 
"""

menu = """
불고기 버거 : 5,500원
치즈 버거 : 4,500원
에그 버거 : 4,000원
콜라 : 2000원
사이다 : 2000원

각 버거 세트 메뉴 있습니다.
세트 메뉴 주문시 500원 할인 됩니다. 
"""
while True:
    print(store_message)
    print("#"*40)
    print(menu)
    print("#"*40)

    burger = input("버거를 선택해주세요 예) 불고기, 치즈, 에그 >>> ")
    drink = input(" 음료를 선택해주세요 예) 콜라, 사이다 >>> ")

    combo = input('  세트메뉴를 선택하시겠어요 ?, 예) 네, 아니오')

    b_price = 0
    d_price = 0
    price = 0

    ############################# 햄버거 주문 #####################################################
    if burger == "불고기":
        b_price = 5500
        print("선택한 버거는 : ", burger, "입니다. 그리고 가격은", b_price,"입니다.")
    elif burger == "치즈":
        b_price = 4500
        print("선택한 버거는 : ", burger, "입니다. 그리고 가격은", b_price,"입니다.")
    elif burger == "에그":
        b_price = 4000
        print("선택한 버거는 : ", burger, "입니다. 그리고 가격은", b_price,"입니다.")
    else:
        print("죄송합니다. 선택한 버거는 잘못된 선택 입니다.")


    ############################### 음료 주문 #####################################################

    if drink == "콜라":
        d_price = 2000
        print("선택한 음료는 : ", drink, "입니다. 그리고 가격은", d_price,"입니다.")
    elif drink == "사이다":
        d_price = 2000
        print("선택한 음료는 : ", drink, "입니다. 그리고 가격은", d_price,"입니다.")

    else:
        print("선택한 음료는 잘못된 선택 입니다.")

    ################################# 총 금액 #####################################################
    # error
    if b_price + d_price == 0:
        print("재주문 해 주시기 바랍니다.")
        break

    if combo == "네":
        price = b_price + d_price
        price -= 500
        print("총 금액은 500원 할인받아서", price, "입니다.")
    elif combo == "아니오":
        price = b_price + d_price
        print(f"총 금액은 {price} 입니다.")
        
    if b_price + d_price > 0:
        print("주문 해주셔서 감사합니다. 잠시만 기다려 주시기 바랍니다.")
        break
# Out:
# bbbbbb       u        u
# b    b       u        u
# b     b      u        u
# bbbbbbb      u        u
# b    b       u        u
# b     b      u        u
# bbbbbbb      uuuuuuuuuu
#
# ########################################
#
# 불고기 버거 : 5,500원
# 치즈 버거 : 4,500원
# 에그 버거 : 4,000원
# 콜라 : 2000원
# 사이다 : 2000원
#
# 각 버거 세트 메뉴 있습니다.
# 세트 메뉴 주문시 500원 할인 됩니다.
#
# ########################################
# 버거를 선택해주세요 예) 불고기, 치즈, 에그 >>> 사과
#  음료를 선택해주세요 예) 콜라, 사이다 >>> 애플
#   세트메뉴를 선택하시겠어요 ?, 예) 네, 아니오네
# 죄송합니다. 선택한 버거는 잘못된 선택 입니다.
# 선택한 음료는 잘못된 선택 입니다.
# 재주문 해 주시기 바랍니다.

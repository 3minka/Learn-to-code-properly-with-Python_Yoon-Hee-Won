# %%
#TclError: no display name and no $DISPLAY environment variable
import os

os.environ['DISPLAY'] = ':1'

# %%
print(os.environ['DISPLAY'])
# Out:
# :0

# %% [markdown]
# if os.environ.get('DISPLAY','') == '':
#     print('no display found. Using :0.0')
#     os.environ.__setitem__('DISPLAY', ':0.0')

# %%
import turtle


#t = turtle.Turtle()

turtle.shape("turtle")#triangle, square, arrow, circle
turtle.bgcolor("red")

# %%
# 사각형
turtle.shape("arrow")
turtle.forward(100) #100픽셀
turtle.left(90) # 90도 왼쪽 회전
turtle.forward(100) #100픽셀
turtle.left(90) # 90도 왼쪽 회전
turtle.forward(100) #100픽셀
turtle.left(90) # 90도 왼쪽 회전
turtle.forward(100) #100픽셀
turtle.left(90) # 90도 왼쪽 회전

# %%
# 삼각형
import turtle 
t = turtle.Turtle()

t.shape("arrow")
t.forward(100) #100픽셀
turtle.left(120) # 120도 왼쪽 회전
t.forward(100) #100픽셀
turtle.left(120) # 120도 왼쪽 회전
t.forward(100) #100픽셀
turtle.left(120) # 120도 왼쪽 회전

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 사각형
t = turtle.Turtle()
t.shape("turtle")
turtle.bgcolor("red")

for i in range(4):
    t.forward(100) #100픽셀
    t.right(90) # 90도 왼쪽 회전

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 반지름 30인 원
from turtle import *

shape("turtle")
color("blue")
write("원그리기 시작")
penup()

goto(100, 100) # x좌표, y좌표
pendown()
circle(30) #반지름

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 오각형
import turtle as t

t.color("green")
t.begin_fill()

for i in range(5):
    t.forward(100)
    t.left(72)
    
t.end_fill()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# t
import turtle
t1 = turtle.Turtle()
t1.shape("turtle")
t1.color("blue")
t1.setx(100)

t2= turtle.Turtle()
t2.shape("turtle")
t2.color("pink")
t2.sety(100)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from turtle import *
shape("turtle")
bgcolor("pink")

speed(0)

colors = ['red', 'green', 'blue', 'black']
pensize(2)
degree=2 #각도

for i in range(300):
    pencolor(colors[i%4])
    forward(i)
    left(90+degree)
    
mainloop()

# %% [markdown]
# ![image.png](attachment:image.png)
